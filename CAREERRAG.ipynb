# %% [markdown]
# <a href="https://colab.research.google.com/github/tanushreekaranth-cell/career-rag-project/blob/main/CAREERRAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# 🤖 CareerRAG - AI Answer Generation
# Uses retrieved PDF information to create an answer
# ============================================================

from transformers import pipeline

print("⏳ Loading local AI model...")

generator = pipeline(
    "text2text-generation",
    model="google/flan-t5-small"
)

print("✅ AI model loaded!")


# ------------------------------------------------------------
# Ask a question
# ------------------------------------------------------------

question = input("\n💬 Ask CareerRAG: ")


# ------------------------------------------------------------
# Convert question into embedding
# ------------------------------------------------------------

question_embedding = model.encode(
    [question],
    convert_to_numpy=True
)


# ------------------------------------------------------------
# Find relevant information from PDFs
# ------------------------------------------------------------

distances, indices = index.search(
    question_embedding.astype("float32"),
    min(3, len(chunks))
)


# ------------------------------------------------------------
# Combine retrieved information
# ------------------------------------------------------------

context = ""

for i in indices[0]:
    context += chunks[i] + "\n"


# ------------------------------------------------------------
# Create prompt
# ------------------------------------------------------------

prompt = f"""
Answer the question using only the information given below.

Context:
{context}

Question:
{question}

Give a simple and clear answer.
"""


# ------------------------------------------------------------
# Generate AI answer
# ------------------------------------------------------------

result = generator(
    prompt,
    max_new_tokens=150
)


answer = result[0]["generated_text"]


# ------------------------------------------------------------
# Display answer
# ------------------------------------------------------------

print("\n" + "=" * 60)
print("🤖 CareerRAG ANSWER")
print("=" * 60)

print(answer)

print("=" * 60)
print("📚 Answer generated using information from your PDFs.")
print("=" * 60)
